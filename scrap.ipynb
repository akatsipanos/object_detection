# %%
import glob
from PIL import Image
import os
directory = 'data/train/'
file_pattern = '*.jpg'
# imgs = os.listdir(os.path.join(directory, file_pattern))
# img = Image.open('data/train/apple_1.jpg')
imgs = glob.glob(os.path.join(directory,file_pattern))
imgs
# Out:
# ['data/train\\apple_1.jpg',
#  'data/train\\apple_10.jpg',
#  'data/train\\apple_11.jpg',
#  'data/train\\apple_12.jpg',
#  'data/train\\apple_13.jpg',
#  'data/train\\apple_14.jpg',
#  'data/train\\apple_15.jpg',
#  'data/train\\apple_16.jpg',
#  'data/train\\apple_17.jpg',
#  'data/train\\apple_18.jpg',
#  'data/train\\apple_19.jpg',
#  'data/train\\apple_2.jpg',
#  'data/train\\apple_20.jpg',
#  'data/train\\apple_21.jpg',
#  'data/train\\apple_22.jpg',
#  'data/train\\apple_23.jpg',
#  'data/train\\apple_24.jpg',
#  'data/train\\apple_25.jpg',
#  'data/train\\apple_26.jpg',
#  'data/train\\apple_27.jpg',
#  'data/train\\apple_28.jpg',
#  'data/train\\apple_29.jpg',
#  'data/train\\apple_3.jpg',
#  'data/train\\apple_30.jpg',
#  'data/train\\apple_31.jpg',
#  'data/train\\apple_32.jpg',
#  'data/train\\apple_33.jpg',
#  'data/train\\apple_35.jpg',
#  'data/train\\apple_36.jpg',
#  'data/train\\apple_37.jpg',
#  'data/train\\apple_38.jpg',
#  'data/train\\apple_39.jpg',
# ...

# %%
import xmltodict 
import json

with open('data/train/apple_1.xml', 'r') as xml_file:
    xml_data = xml_file.read()

# Convert XML to dictionary
data_dict = xmltodict.parse(xml_data)

data_dict
# Out:
# {'annotation': {'folder': 'train',
#   'filename': 'apple_1.jpg',
#   'path': 'C:\\tensorflow1\\models\\research\\object_detection\\images\\train\\apple_1.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '0', 'height': '0', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'apple',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '8', 'ymin': '15', 'xmax': '331', 'ymax': '349'}}}}
